# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #We use encoding="unicode_escape" to avoid encoding error

# %%
df=pd.read_csv(r"C:\Users\320296257\Desktop\Data analytics\Python\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# #df.shape is a property and is used to know the rows and column

# %%
df.shape
# Out:
# (11251, 15)

# %% [markdown]
# #df.head is used to visualise the first 5 rows

# %%
df.head
# Out:
# <bound method NDFrame.head of        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %% [markdown]
# #df.head() is a function, and it is used to visualize the rows. We call it

# %%
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# #df.info() is used to know the info of data, such as how many rows and  column are there, what type of data type is the rows have, whether the value is null or not.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), str(8)
# memory usage: 1.3 MB

# %% [markdown]
# #df.drop is used to delete the data, axis=1 is used for column, which means deletion of the column.

# %%
df.drop(['Status','unnamed1'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  str
#  2   Product_ID        11251 non-null  str
#  3   Gender            11251 non-null  str
#  4   Age Group         11251 non-null  str
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  str
#  8   Zone              11251 non-null  str
#  9   Occupation        11251 non-null  str
#  10  Product_Category  11251 non-null  str
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.1 MB

# %% [markdown]
# #df.isnull() is used to know the null values in my data, in the form of True or False.

# %%
df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %% [markdown]
# #df.isnull().sum() is used to know the null value in numeric, how many null values are there in column-wise.

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# #df.isnull().sum().sum() is used to check the total number of not null values in the entire dataframe...
# First .sum() gives missing values per column.
# Second .sum() adds all columns together.
# Total missing values in the whole dataframe = 12

# %%
df.isnull().sum().sum()
# Out:
# np.int64(12)

# %% [markdown]
# #np.int64(12) means 12 values are null or missing, which is stored as a numpy datatype.

# %% [markdown]
# #df.dropna(inplace=True) are used to delete null data

# %%
df.dropna(inplace=True)

# %% [markdown]
# #inplace=True: Make changes directly in the original dataframe/object.
#
# Without inplace=True, pandas usually creates a new modified copy and leaves the original unchanged.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  str
#  2   Product_ID        11239 non-null  str
#  3   Gender            11239 non-null  str
#  4   Age Group         11239 non-null  str
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  str
#  8   Zone              11239 non-null  str
#  9   Occupation        11239 non-null  str
#  10  Product_Category  11239 non-null  str
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), str(8)
# memory usage: 1.2 MB

# %%
df.shape
# Out:
# (11239, 13)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['Amount']=df['Amount'].astype('int')

# %% [markdown]
# #Above is used to change the daytatype

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  str
#  2   Product_ID        11239 non-null  str
#  3   Gender            11239 non-null  str
#  4   Age Group         11239 non-null  str
#  5   Age               11239 non-null  int64
#  6   Marital_Status    11239 non-null  int64
#  7   State             11239 non-null  str
#  8   Zone              11239 non-null  str
#  9   Occupation        11239 non-null  str
#  10  Product_Category  11239 non-null  str
#  11  Orders            11239 non-null  int64
#  12  Amount            11239 non-null  int64
# dtypes: int64(5), str(8)
# memory usage: 1.2 MB

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='str')

# %% [markdown]
# #df.rename is used to rename the column header

# %%
df.rename(columns = {'Marital_Status':'shaadi'}, inplace=True)

# %% [markdown]
# #df.describe is used to describe the entire column

# %%
df.describe()
# Out:
#             User_ID           Age        shaadi        Orders        Amount
# count  1.123900e+04  11239.000000  11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357      0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866      0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000      0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000      0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000      1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000

# %% [markdown]
# #below is used to describe the particular columns

# %%
df[['Age', 'Amount']].describe()
# Out:
#                 Age        Amount
# count  11239.000000  11239.000000
# mean      35.410357   9453.610553
# std       12.753866   5222.355168
# min       12.000000    188.000000
# 25%       27.000000   5443.000000
# 50%       33.000000   8109.000000
# 75%       43.000000  12675.000000
# max       92.000000  23952.000000

# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\320296257\Desktop\Data analytics\Python\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %% [markdown]
# #below is used to make a bar chart where sns. countplot is a function, and x='Gender' is the x-axis

# %%
a = sns.countplot(x='Gender',data=df)

# %% [markdown]
# #below is used to write a label on the bar

# %%
a = sns.countplot(x='Gender',data=df)
for bar in a.containers:
 a.bar_label(bar)

# %% [markdown]
# #df.groupby(['Gender']) means Group by Gender, ['Amount'] means select amount, .sum() means sum sales amount, .sort_values(by='Amount', ascending=False) means sort highest to lowest.

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# %%
sns. barplot(x='Gender',y='Amount',data= sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# #From the above graph, we can see that most of the buyers are females.

# %% [markdown]
# #on the basis of Age, we are going to analyse the data

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %% [markdown]
# #on the basis of the age group, the following are the people who order

# %%
sns.countplot(x='Age Group', data= df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %% [markdown]
# #hue is used to show the symbol that colors are for males and which are for females

# %%
sns.countplot(x='Age Group',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
a=sns.countplot(x='Age Group',hue='Gender',data=df)
for bar in a.containers:
    a.bar_label(bar)

# %%
sales_age=df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x='Age Group',y='Amount',data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# #from the above graph we can see that most of the buyers are between the age group of 26-35 female

# %%
df=pd.read_csv(r"C:\Users\320296257\Desktop\Data analytics\Python\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %% [markdown]
# #total number of orders from top 10 states.
# sales_state = df.groupby(['State'], as_index = False)['Orders'].sum().sort_values(by = 'Orders',ascending = False).head(10)
# #at the end .head() is used to only view 10 states

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

# %% [markdown]
# #.head() is used to plot only 10 state

# %%
sns.set(rc={'figure.figsize':(15,5)})

# %% [markdown]
# #below is used to resize the plot

# %%
sns.barplot(x='State',y='Amount',data=sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(x='State',y='Orders',data=sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# #from the above plot, we can see that most of the orders are from Uttar Pradesh, Maharashtra, and Karnataka

# %%
df=pd.read_csv(r"C:\Users\320296257\Desktop\Data analytics\Python\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})

sns.barplot(x='State', y='Orders', data=sales_state, color='pink')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
a = sns.countplot(data=df,x='Marital_Status')
sns.set(rc={'figure.figsize':(5,5)}) 
for bars in a.containers:
     a.bar_label(bars)

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\320296257\Desktop\Data analytics\Python\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding='unicode_escape')

# %%
sales_state = df.groupby(['Marital_Status','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(5,5)})
sns.barplot(x='Marital_Status',y='Amount',data=sales_state,hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='str')

# %% [markdown]
# *from the above graph, we can see that most of the buyers are female

# %% [markdown]
# #Occupation

# %%
sns.set(rc={'figure.figsize':(20,5)})
a = sns. countplot(x='Occupation',data=df)
for bar in a.containers:
    a.bar_label(bar)

# %%
sns.set(rc={'figure.figsize':(25,5)})
a = sns. countplot(x='Product_Category',data=df)
for bar in a.containers:
    a.bar_label(bar)

# %%
sales_state = df.groupby(['Product_Category','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Product_Category',y='Amount',data=sales_state,hue='Gender')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# #from the above graph we can see that most of the sold products are food

# %%
sns.set(rc={'figure.figsize':(25,5)})
a = sns.countplot(x='Product_Category',data=df)
for bar in a.containers:
    a.bar_label(bar)

# %%
sales_state = df.groupby(['Product_ID','Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Product_ID',y='Amount',data=sales_state,hue='Gender')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Amount'>

# %% [markdown]
# #Conclusion

# %%
From the analysis, it is found that the majority of buyers are married women in the age group 26-35 years from UP, Maharashtra, Karnataka, working in IT, Healthcare, and aviation, who are most likely buying products for clothing, food, and electronic gadgets.
